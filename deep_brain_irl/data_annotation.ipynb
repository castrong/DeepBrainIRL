# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Run 0 from sp_20210126. 13-52-24
# taking off 1 second from 725 --> 724 at the end bc brain data runs out 
sp_20210126_13_52_24_timestamps = [122, 188.5, 193.5, 283, 358, 370, 411, 443, 501, 534.5, 546, 560, 564, 573, 584, 588, 594, 600, 603.5, 625, 658, 698.5, 702.5, 724]
# For 534.5 it's both a turn and transition.
sp_20210126_13_52_24_labels = ['straight', 'turning', 'straight', 'dirt', 'transition', 'dirt', 'transition', 'dirt', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight']
sp_20210126_13_52_24_filename = '20210126SP_13-52-24_scenario_labels.npz'

# %%
diffs = np.diff(sp_20210126_13_52_24_timestamps)
indices = np.array([ind for ind, label in enumerate(sp_20210126_13_52_24_labels) if label == 'straight'])
diffs[indices]
# Out:
# array([66.5, 89.5, 33.5, 14. ,  9. ,  4. ,  6. , 21.5, 40.5, 21.5])

# %%
# Run 1 from sp_20210126. 14-08-22
# 6:46 hits a car that spawns right in front. 
# 7:37 wasn't sure whether turn or sraight bc road just turns. 9:43 as well. Notated as turns.  
sp_20210126_14_08_22_timestamps = [101, 130, 150, 166, 182, 187.5, 198, 201, 208, 217, 250, 306, 319, 380, 382.5, 404, 457, 463, 495, 516, 539, 563, 583, 588, 635.5, 648, 650, 654, 697.5, 707]
# For 534.5 it's both a turn and transition.
sp_20210126_14_08_22_labels = ['transition', 'straight', 'turning', 'transition', 'turning', 'straight', 'turning', 'straight', 'turning', 'straight', 'dirt', 'transition', 'dirt', 'straight', 'transition', 'straight', 'turning', 'straight', 'dirt', 'transition', 'dirt', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'turning']
sp_20210126_14_08_22_filename = '20210126SP_14-08-22_scenario_labels.npz'

# %%
diffs = np.diff(sp_20210126_14_08_22_timestamps)
indices = np.array([ind for ind, label in enumerate(sp_20210126_14_08_22_labels) if label == 'straight'])
diffs[indices]
# Out:
# array([20. , 10.5,  7. , 33. ,  2.5, 53. , 32. , 20. , 47.5,  2. , 43.5])

# %%
# 6:37 they seemed to go the wrong way. marked it down as still dirt. 
# 10:25 car spawned and hit it again, it was the VW van again xD. 
# 11:20 another car spawns and they hit it
sp_20210126_14_23_30_timestamps = [114, 130, 151.5, 155, 181, 185, 251, 255, 283.5, 325, 335, 352, 369, 400, 402.5, 428, 432, 448, 463, 549, 552, 588.5, 619, 666, 670.5, 695, 720]
sp_20210126_14_23_30_labels = ['transition', 'straight', 'turning', 'transition', 'turning', 'straight', 'turning', 'straight', 'dirt', 'transition', 'dirt', 'transition', 'dirt', 'turning', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition']
sp_20210126_14_23_30_filename = '20210126SP_14-23-30_scenario_labels.npz'

# %%
# 497 rolling stoplight into transition
sp_20210126_14_38_49_timestamps = [133, 180, 210, 224.5, 255, 289, 292.5, 307, 311.5, 339, 366, 370, 377.5, 396, 399, 410, 432.5, 452, 481, 485, 492.5, 497, 523, 557, 562, 565.5, 578, 588, 591.5, 631.5, 649, 676, 679, 712]
sp_20210126_14_38_49_labels = ['straight', 'dirt', 'transition', 'dirt', 'straight', 'turning', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'turning', 'straight', 'transition', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight', 'transition', 'straight', 'turning', 'straight']
sp_20210126_14_38_49_filename = '20210126SP_14-38-49_scenario_labels.npz'

# %%
print("3: len timestamps: ", len(sp_20210126_14_38_49_timestamps))
print("3: len labels: ", len(sp_20210126_14_38_49_labels))

print("2: len timestamps: ", len(sp_20210126_14_23_30_timestamps))
print("2: len labels: ", len(sp_20210126_14_23_30_labels))

print("1: len timestamps: ", len(sp_20210126_14_08_22_timestamps))
print("1: len labels: ", len(sp_20210126_14_08_22_labels))

print("0: len timestamps: ", len(sp_20210126_13_52_24_timestamps))
print("0: len labels: ", len(sp_20210126_13_52_24_labels))
# Out:
# 3: len timestamps:  34
# 3: len labels:  33
# 2: len timestamps:  27
# 2: len labels:  26
# 1: len timestamps:  30
# 1: len labels:  29
# 0: len timestamps:  24
# 0: len labels:  23

# %% [markdown]
# Now that we've labeled them all, let's output them as .npy files.

# %%
all_timestamps = [sp_20210126_13_52_24_timestamps, sp_20210126_14_08_22_timestamps, sp_20210126_14_23_30_timestamps, sp_20210126_14_38_49_timestamps]
all_labels = [sp_20210126_13_52_24_labels, sp_20210126_14_08_22_labels, sp_20210126_14_23_30_labels, sp_20210126_14_38_49_labels]

base_path = "./Data/LogAndLabelData/"
all_filenames = [sp_20210126_13_52_24_filename, sp_20210126_14_08_22_filename, sp_20210126_14_23_30_filename, sp_20210126_14_38_49_filename]
all_filenames = [base_path + filename for filename in all_filenames]

for (timestamps, labels, filename) in zip(all_timestamps, all_labels, all_filenames):
    np.savez(filename, timestamps=timestamps, labels=labels)

# %% [markdown]
# Let's test loading the files

# %%
def load_scenario_label(filename):
    data = np.load(filename)
    timestamps = data['timestamps']
    labels = data['labels']
    return timestamps, labels

timestamps, labels = load_scenario_label('./Data/LogAndLabelData/20210126SP_13-52-24_scenario_labels.npz')

# %% [markdown]
# #### Map annotation

# %%
line_1 = [[1044-400, 0], [81285+400, 0]]
line_2 = [[0, 2464-1650], [0, 96116+1650]]
line_3 = [[6577, 859-400], [6572, 6572+1900]]
line_4 = [[11507, 859-400], [11507, 6572+1900]] 
line_5 = [[16427, 859-400], [16427, 6572+1900]]
line_6 = [[22188, 859-400], [22188, 24610+400]]
line_7 = [[42719, 859-400], [42719, 53336+400]]
line_8 = [[49291, 859-400], [49291, 29526+400]]
line_9 = [[55863, 859-400], [55863, 12266+400]]
line_10 = [[66542, 859-400], [66542, 12266+400]]

line_11 = [[74758, 859-400], [74758, 29526+400]]
line_12 = [[82151, 859-400], [82151, 96117+1600]]
line_13 = [[1044-400, 9037], [21125+400, 9037]]
line_14 = [[43579-400, 7394], [48425+400, 7394]]
line_15 = [[1044-400, 25467], [41855+400, 25467]]
line_16 = [[50159-400, 13144], [73895+400, 13144]]
line_17 = [[75619-400, 22181], [81285+400, 22181]]
line_18 = [[43579-400, 30396], [81285+400, 30396]]
line_19 = [[8215, 26314-400], [8215, 40166+400]]
line_20 = [[16430, 26314-400], [16430, 53336+400]]

line_21 = [[9079-400, 32860], [15565+400, 32860]]
line_22 = [[1044-400, 41076], [15565+400, 41076]]
line_23 = [[1044-400, 54220], [81285+400, 54220]]
line_24 = [[9858, 55254-400], [9858, 77806+400]]
line_25 = [[26288, 55254-400], [26288, 97526+400]]
line_26 = [[36968, 55254-400], [36968, 65666+400]]
line_27 = [[48469, 55254-400], [48469, 97526+400]]
line_28 = [[53398, 55254-400], [53398, 60736+400]]
line_29 = [[63256, 55254-400], [63256, 81916+400]]
line_30 = [[75579, 55254-400], [75579, 68136+400]]

line_31 = [[1044-400, 61613], [8805+400, 61613]]
line_32 = [[27159-400, 66542], [48469-700, 66542]]
line_33 = [[49329-400, 61613], [62405+400, 61613]]
line_34 = [[64119-400, 69007], [81285+400, 69007]]
line_35 = [[1044-400, 68185], [8805+400, 68185]]
line_36 = [[1044-400, 73114], [8805+400, 73114]]
line_37 = [[1044-400, 78865], [25435+400, 78865]]
line_38 = [[49329-400, 74758], [62405+400, 74758]]
line_39 = [[69828, 69859-400], [69828, 81916+400]]
line_40 = [[70699-400, 76401], [81285+400, 76401]]

line_41 = [[74758, 77259-400], [74758, 81916+400]]
line_42 = [[19716, 79719-400], [19716, 97526+400]]
line_43 = [[49329-400, 82973], [81285+400, 82973]]
line_44 = [[1044-400, 91188], [18665+400, 91188]]
line_45 = [[27159-400, 90366], [48469-700, 90366]]
line_46 = [[54220, 83819-400], [54220, 97526+400]]
line_47 = [[1044-400, 98581], [81285+400, 98581]]
line_48 = [[36146, 91229-400], [36146, 97526+400]]
line_49 = [[43540, 91229-400], [43540, 97526+400]]



lines = [line_1, line_2, line_3, line_4, line_5, line_6, line_7, line_8, line_9, line_10, 
         line_11, line_12, line_13, line_14, line_15, line_16, line_17, line_18, line_19, line_20, 
         line_21, line_22, line_23, line_24, line_25, line_26, line_27, line_28, line_29, line_30, 
         line_31, line_32, line_33, line_34, line_35, line_36, line_37, line_38, line_39, line_40, 
         line_41, line_42, line_43, line_44, line_45, line_46, line_47, line_48, line_49]

# %%
def plot_line(line, index):
    x1, y1 = line[0]
    x2, y2 = line[1]
    plt.plot([x1, x2], [y1, y2], color='black', linewidth=1)
    # write the number i next to each line
    plt.text((x1+x2)/2, (y1+y2)/2, str(index), fontsize=10, color='red')

plt.figure() 
for i, line in enumerate(lines):
    plot_line(line, i+1)

plt.axis('equal')
plt.gca().invert_yaxis()

# %% [markdown]
# Write out to file

# %%
np.savez('./Data/LogAndLabelData/map_centerlines.npz', lines=lines)

# %%
def load_centerlines(filename):
    data = np.load(filename)
    return data['lines']

lines_new = load_centerlines('./Data/LogAndLabelData/map_centerlines.npz')
plt.figure() 
for i, line in enumerate(lines_new):
    plot_line(line, i+1)

plt.axis('equal')
plt.gca().invert_yaxis()
